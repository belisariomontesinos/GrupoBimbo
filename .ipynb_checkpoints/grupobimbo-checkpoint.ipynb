# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import patches as mpatches

# %%
data = pd.read_csv("~/schoolfolder/githubstuff/GrupoBimbo/bimbosample.csv") 
clients = pd.read_csv("~/schoolfolder/githubstuff/GrupoBimbo/cliente_tabla.csv") 
products = pd.read_csv("~/schoolfolder/githubstuff/GrupoBimbo/producto_tabla.csv") 
location = pd.read_csv("~/schoolfolder/githubstuff/GrupoBimbo/town_state.csv") 
products.head()
# Out:
#    Producto_ID                          NombreProducto
# 0            0                       NO IDENTIFICADO 0
# 1            9               Capuccino Moka 750g NES 9
# 2           41  Bimbollos Ext sAjonjoli 6p 480g BIM 41
# 3           53          Burritos Sincro 170g CU LON 53
# 4           72     Div Tira Mini Doradita 4p 45g TR 72

# %%
#data.info()
data.describe()
#data.shape
# Out:
#                Semana      Agencia_ID        Canal_ID        Ruta_SAK  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         5.951067     2529.706054        1.382342     2114.461829
# std          2.013808     4056.139340        1.460692     1487.632433
# min          3.000000     1110.000000        1.000000        1.000000
# 25%          4.000000     1311.000000        1.000000     1161.000000
# 50%          6.000000     1614.000000        1.000000     1285.000000
# 75%          8.000000     2036.000000        1.000000     2802.000000
# max          9.000000    25759.000000       11.000000     9970.000000
#
#          Cliente_ID     Producto_ID   Venta_uni_hoy       Venta_hoy  \
# count  1.000000e+06  1000000.000000  1000000.000000  1000000.000000
# mean   1.801974e+06    20838.915541        7.322536       68.496290
# std    1.839772e+06    18665.888986       21.825837      371.125366
# min    2.600000e+01       41.000000        0.000000        0.000000
# 25%    3.574020e+05     1242.000000        2.000000       16.760000
# 50%    1.193148e+06    30549.000000        3.000000       30.000000
# 75%    2.373150e+06    37425.000000        7.000000       56.100000
# max    1.169326e+07    49994.000000     3472.000000   227888.640000
#
#        Dev_uni_proxima     Dev_proxima  Demanda_uni_equil
# count   1000000.000000  1000000.000000     1000000.000000
# mean          0.131076        1.273099           7.237505
# std           5.869484       46.166875          21.670671
# min           0.000000        0.000000           0.000000
# 25%           0.000000        0.000000           2.000000
# 50%           0.000000        0.000000           3.000000
# 75%           0.000000        0.000000           6.000000
# max        5030.000000    40240.000000        3472.000000

# %% [markdown]
# _________

# %% [markdown]
# # Is there a difference in Sales volume for items packaged by pieces? #

# %% [markdown]
# ### Null Hypothesis: There is no significance in packaging by pieces ###

# %% [markdown]
# _____

# %% [markdown]
# Split product name (NombreProducto) column from products table - We want to filter for products with a number and a p(for pieces) nect to their name.
# Ex. Bimbollos Ext sAjonjoli 6p 480g BIM 41 - the 6p means 6 pieces, we want to group these items together to see how they perform.

# %%
products['short_name'] = products.NombreProducto.str.extract('^(\D*)', expand=False)
products['brand'] = products.NombreProducto.str.extract('^.+\s(\D+) \d+$', expand=False)
w = products.NombreProducto.str.extract('(\d+)(Kg|g)', expand=True)
products['weight'] = w[0].astype('float')*w[1].map({'Kg':1000, 'g':1})
products['pieces'] =  products.NombreProducto.str.extract('(\d+)p ', expand=False).astype('float')

# %%
#products.head()
products.describe
# Out:
# <bound method NDFrame.describe of       Producto_ID                                  NombreProducto  \
# 0               0                               NO IDENTIFICADO 0
# 1               9                       Capuccino Moka 750g NES 9
# 2              41          Bimbollos Ext sAjonjoli 6p 480g BIM 41
# 3              53                  Burritos Sincro 170g CU LON 53
# 4              72             Div Tira Mini Doradita 4p 45g TR 72
# ...           ...                                             ...
# 2587        49992             Tostado Integral 180g MTA WON 49992
# 2588        49993             Tostado Integral 180g TAB WON 49993
# 2589        49994      Tostado Int 0pct Grasa Azuc 200g WON 49994
# 2590        49996  Tostado Int 0pct Grasa Azuc 200g MTA WON 49996
# 2591        49997  Tostado Int 0pct Grasa Azuc 200g TAB WON 49997
#
#                     short_name         brand  weight  pieces  normal
# 0             NO IDENTIFICADO   IDENTIFICADO     NaN     NaN    True
# 1              Capuccino Moka            NES   750.0     NaN    True
# 2     Bimbollos Ext sAjonjoli            BIM   480.0     6.0   False
# 3             Burritos Sincro            LON   170.0     NaN    True
# 4      Div Tira Mini Doradita             TR    45.0     4.0   False
# ...                        ...           ...     ...     ...     ...
# 2587         Tostado Integral            WON   180.0     NaN    True
# 2588         Tostado Integral            WON   180.0     NaN    True
# 2589              Tostado Int            WON   200.0     NaN    True
# 2590              Tostado Int            WON   200.0     NaN    True
# 2591              Tostado Int            WON   200.0     NaN    True
#
# [2592 rows x 7 columns]>

# %% [markdown]
# _____

# %% [markdown]
# ## Look for outliers and get rid of them ##

# %% [markdown]
# ### Graph the numeric columns ###

# %% [markdown]
# First pieces, since that is the column we really care for.

# %%
products['pieces'].describe()
# Out:
# count    1117.000000
# mean       10.567592
# std        11.133603
# min         1.000000
# 25%         4.000000
# 50%         8.000000
# 75%        12.000000
# max       200.000000
# Name: pieces, dtype: float64

# %%
sns.boxplot(x='pieces', data=products)

# %%
 products.loc[products['pieces'] > 75]
# Out:
#       Producto_ID                               NombreProducto  \
# 59            739                   Saladas 200p 2 4Kg LAR 739
# 1724        36830  Bon o Bon Leche Two Pack 104p 30g RIC 36830
# 1969        40889             Orejitas Panera 100p 5g TR 40889
#
#                      short_name brand  weight  pieces  normal
# 59                     Saladas    LAR  4000.0   200.0   False
# 1724  Bon o Bon Leche Two Pack    RIC    30.0   104.0   False
# 1969           Orejitas Panera     TR     5.0   100.0   False

# %% [markdown]
# We determined these are not outliers, just high pieces products.

# %%
products['weight'].describe()
# Out:
# count     2483.000000
# mean       413.919050
# std       1782.184389
# min          4.000000
# 25%         80.000000
# 50%        180.000000
# 75%        400.000000
# max      42000.000000
# Name: weight, dtype: float64

# %%
sns.boxplot(x='weight', data=products)

# %%
 products.loc[products['weight'] > 7000]
# Out:
#       Producto_ID                            NombreProducto  \
# 27            162                       Molido 25Kg WON 162
# 90           1156            Tortillinas 50p 1 31Kg TR 1156
# 152          2185           Molido Industrial 25Kg BIM 2185
# 160          2438                      Molido 25Kg BIM 2438
# 345          8766       Cajeta Quemada Cubeta 25Kg COR 8766
# 1198        34909           Marias a Granel 3 8Kg LAR 34909
# 1567        36277  Exhibidor Sanissimo 2 42Kg CJM SAN 36277
# 2199        43348       Tortillinas 50p 1 31Kg MTA TR 43348
# 2237        44833                    Lors 18Kg CU MLA 44833
# 2315        46113       Tortillinas 50p 1 31Kg TAB TR 46113
#
#                   short_name brand   weight  pieces  normal
# 27                   Molido    WON  25000.0     NaN    True
# 90              Tortillinas     TR  31000.0    50.0   False
# 152       Molido Industrial    BIM  25000.0     NaN    True
# 160                  Molido    BIM  25000.0     NaN    True
# 345   Cajeta Quemada Cubeta    COR  25000.0     NaN    True
# 1198        Marias a Granel    LAR   8000.0     NaN    True
# 1567    Exhibidor Sanissimo    SAN  42000.0     NaN    True
# 2199            Tortillinas     TR  31000.0    50.0   False
# 2237                   Lors    MLA  18000.0     NaN    True
# 2315            Tortillinas     TR  31000.0    50.0   False

# %% [markdown]
# Exhibidor is not a product (edible) - lets remove it from our data.

# %% [markdown]
# ### Drop the exhibidor row ###

# %%
i =  products.loc[products['weight'] > 35000].index
products = products.drop(i)
products = products.reset_index(drop=True)
products
# Out:
#       Producto_ID                                  NombreProducto  \
# 0               0                               NO IDENTIFICADO 0
# 1               9                       Capuccino Moka 750g NES 9
# 2              41          Bimbollos Ext sAjonjoli 6p 480g BIM 41
# 3              53                  Burritos Sincro 170g CU LON 53
# 4              72             Div Tira Mini Doradita 4p 45g TR 72
# ...           ...                                             ...
# 2586        49992             Tostado Integral 180g MTA WON 49992
# 2587        49993             Tostado Integral 180g TAB WON 49993
# 2588        49994      Tostado Int 0pct Grasa Azuc 200g WON 49994
# 2589        49996  Tostado Int 0pct Grasa Azuc 200g MTA WON 49996
# 2590        49997  Tostado Int 0pct Grasa Azuc 200g TAB WON 49997
#
#                     short_name         brand  weight  pieces  normal
# 0             NO IDENTIFICADO   IDENTIFICADO     NaN     NaN    True
# 1              Capuccino Moka            NES   750.0     NaN    True
# 2     Bimbollos Ext sAjonjoli            BIM   480.0     6.0   False
# 3             Burritos Sincro            LON   170.0     NaN    True
# 4      Div Tira Mini Doradita             TR    45.0     4.0   False
# ...                        ...           ...     ...     ...     ...
# 2586         Tostado Integral            WON   180.0     NaN    True
# 2587         Tostado Integral            WON   180.0     NaN    True
# 2588              Tostado Int            WON   200.0     NaN    True
# 2589              Tostado Int            WON   200.0     NaN    True
# 2590              Tostado Int            WON   200.0     NaN    True
#
# [2591 rows x 7 columns]

# %% [markdown]
# _____

# %% [markdown]
# ## Create 2 datasets - products by pieces vs regular products (not by pieces) ##

# %%
products['normal'] = pd.DataFrame(pd.isna(products['pieces']))
products.head()
# Out:
#    Producto_ID                          NombreProducto  \
# 0            0                       NO IDENTIFICADO 0
# 1            9               Capuccino Moka 750g NES 9
# 2           41  Bimbollos Ext sAjonjoli 6p 480g BIM 41
# 3           53          Burritos Sincro 170g CU LON 53
# 4           72     Div Tira Mini Doradita 4p 45g TR 72
#
#                  short_name         brand  weight  pieces  normal
# 0          NO IDENTIFICADO   IDENTIFICADO     NaN     NaN    True
# 1           Capuccino Moka            NES   750.0     NaN    True
# 2  Bimbollos Ext sAjonjoli            BIM   480.0     6.0   False
# 3          Burritos Sincro            LON   170.0     NaN    True
# 4   Div Tira Mini Doradita             TR    45.0     4.0   False

# %%
nopieces = products.loc[products['normal'] == True]
pieces = products.loc[products['normal'] == False]
pieces.describe
# Out:
# <bound method NDFrame.describe of       Producto_ID                          NombreProducto  \
# 2              41  Bimbollos Ext sAjonjoli 6p 480g BIM 41
# 4              72     Div Tira Mini Doradita 4p 45g TR 72
# 15            123        Super Bollos 5in 8p 540g WON 123
# 16            125                  Bollos 8p 450g WON 125
# 17            131          Bollos BK 4in 36p 1635g SL 131
# ...           ...                                     ...
# 2572        49781  Tortillinas 12p 310g Prom MTA TR 49781
# 2573        49782    Tortillinas 12p 310g NW MTA TR 49782
# 2576        49860        Gansito ME 5p 250g MTA MLA 49860
# 2578        49920       Conchas 3p 180g Prom TAB TR 49920
# 2579        49928              Dona 1p 26g Tira BIM 49928
#
#                     short_name brand  weight  pieces  normal
# 2     Bimbollos Ext sAjonjoli    BIM   480.0     6.0   False
# 4      Div Tira Mini Doradita     TR    45.0     4.0   False
# 15               Super Bollos    WON   540.0     8.0   False
# 16                     Bollos    WON   450.0     8.0   False
# 17                  Bollos BK     SL  1635.0    36.0   False
# ...                        ...   ...     ...     ...     ...
# 2572              Tortillinas     TR   310.0    12.0   False
# 2573              Tortillinas     TR   310.0    12.0   False
# 2576               Gansito ME    MLA   250.0     5.0   False
# 2578                  Conchas     TR   180.0     3.0   False
# 2579                     Dona    BIM    26.0     1.0   False
#
# [1117 rows x 7 columns]>

# %% [markdown]
# ## Data Exploration ##

# %% [markdown]
# ### Basic Comparison ###

# %%
pieces.describe()
# Out:
#         Producto_ID        weight       pieces
# count   1117.000000   1078.000000  1117.000000
# mean   32628.052820    370.646568    10.567592
# std    13212.481168   1651.507962    11.133603
# min       41.000000      4.000000     1.000000
# 25%    31232.000000     78.000000     4.000000
# 50%    35301.000000    180.000000     8.000000
# 75%    41829.000000    397.500000    12.000000
# max    49928.000000  31000.000000   200.000000

# %%
nopieces.describe()
# Out:
#         Producto_ID        weight  pieces
# count   1475.000000   1405.000000     0.0
# mean   32563.108475    447.120285     NaN
# std    12848.459703   1876.192879     NaN
# min        0.000000      5.000000     NaN
# 25%    31661.500000     80.000000     NaN
# 50%    35144.000000    180.000000     NaN
# 75%    37598.500000    400.000000     NaN
# max    49997.000000  42000.000000     NaN
